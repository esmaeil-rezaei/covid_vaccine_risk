# %%
import pandas as pd

# %%
df = pd.read_csv("../artifacts/data.csv")
df.head()
# Out:
#    Patient ID  Age  Gender Vaccination Date Vaccine Dose  \
# 0         879   82    Male       2022-06-06     2nd Dose
# 1         492   48  Female       2020-09-11      Booster
# 2         146   80    Male       2023-02-03     1st Dose
# 3         739   74    Male       2020-12-29      Booster
# 4         209   30    Male       2020-05-29     2nd Dose
#
#   Pre-existing Conditions Heart Attack Date  Heart Attack Related to Vaccine  \
# 0                  Asthma               NaN                            False
# 1           Heart Disease               NaN                            False
# 2            Hypertension               NaN                            False
# 3                Diabetes        2021-01-10                             True
# 4                  Asthma               NaN                            False
#
#      Location Blood Pressure  Cholesterol Level   BMI Smoking History  \
# 0   San Diego       Very Low                180  35.0              No
# ...

# %%
df[['Blood Pressure', 'Diabetes Status', 'Gender', 'Heart Attack Related to Vaccine', 'Location', 'Pre-existing Conditions', 'Smoking History', 'Vaccine Dose']]
# Out:
#      Blood Pressure Diabetes Status  Gender  Heart Attack Related to Vaccine  \
# 0          Very Low             Yes    Male                            False
# 1               Low             Yes  Female                            False
# 2         Very High             Yes    Male                            False
# 3              High              No    Male                             True
# 4              High             Yes    Male                            False
# ...             ...             ...     ...                              ...
# 9995       Very Low             Yes    Male                             True
# 9996       Very Low             Yes  Female                            False
# 9997         Normal             Yes    Male                             True
# 9998            Low             Yes  Female                             True
# 9999           High              No  Female                            False
#
# ...

# %%
df.select_dtypes(include=["number"]).columns.difference(['User_ID'])
# Out:
# Index(['Age', 'BMI', 'Cholesterol Level', 'Patient ID'], dtype='object')

# %%
df['Heart Attack Date'] = pd.to_datetime(df['Heart Attack Date'], errors='coerce')
df['Heart Attack Date'].apply(lambda x: 1 if x else 0)
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 9995    1
# 9996    1
# 9997    1
# 9998    1
# 9999    1
# Name: Heart Attack Date, Length: 10000, dtype: int64

# %%
df['Heart Attack Related to Vaccine'].astype(int).sum()
# Out:
# 0       0
# 1       0
# 2       0
# 3       1
# 4       0
#        ..
# 9995    1
# 9996    0
# 9997    1
# 9998    1
# 9999    0
# Name: Heart Attack Related to Vaccine, Length: 10000, dtype: int64
