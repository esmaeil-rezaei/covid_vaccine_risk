# %%
import pandas as pd

# %%
df = pd.read_csv("../artifacts/data.csv")
df.head()
# Out:
#    Patient ID  Age  Gender Vaccination Date Vaccine Dose  \
# 0         392   27  Female       2022-01-16     2nd Dose
# 1         448   77  Female       2023-02-17     2nd Dose
# 2         953   42  Female       2022-09-17     2nd Dose
# 3         410   41  Female       2022-02-03     2nd Dose
# 4         977   28    Male       2022-03-04     2nd Dose
#
#   Pre-existing Conditions Heart Attack Date  Heart Attack Related to Vaccine  \
# 0           Heart Disease               NaN                            False
# 1           Heart Disease        2023-03-24                             True
# 2                     NaN               NaN                            False
# 3                     NaN        2012-08-19                            False
# 4            Hypertension               NaN                            False
#
#    Severity  Outcome     Location Blood Pressure  Cholesterol Level   BMI  \
# 0       NaN      NaN   Washington      Very High                350  19.0
# 1       NaN      NaN       Denver           High                220  39.0
# 2       NaN      NaN     San Jose      Very High                250  27.0
# 3       NaN      NaN  Los Angeles           High                180  28.4
# 4       NaN      NaN      Chicago      Very High                350  37.7
#
#   Smoking History Diabetes Status
# 0             Yes             Yes
# 1             Yes             Yes
# 2              No             Yes
# 3             Yes              No
# 4             Yes             Yes

# %%
df[['Blood Pressure', 'Diabetes Status', 'Gender', 'Heart Attack Related to Vaccine', 'Location', 'Pre-existing Conditions', 'Smoking History', 'Vaccine Dose']]
# Out:
#      Blood Pressure Diabetes Status  Gender  Heart Attack Related to Vaccine  \
# 0         Very High             Yes  Female                            False
# 1              High             Yes  Female                             True
# 2         Very High             Yes  Female                            False
# 3              High              No  Female                            False
# 4         Very High             Yes    Male                            False
# ...             ...             ...     ...                              ...
# 9995            Low             Yes  Female                            False
# 9996           High             Yes    Male                            False
# 9997            Low              No    Male                            False
# 9998           High              No    Male                            False
# 9999         Normal             Yes  Female                            False
#
#           Location Pre-existing Conditions Smoking History Vaccine Dose
# 0       Washington           Heart Disease             Yes     2nd Dose
# 1           Denver           Heart Disease             Yes     2nd Dose
# 2         San Jose                     NaN              No     2nd Dose
# 3      Los Angeles                     NaN             Yes     2nd Dose
# 4          Chicago            Hypertension             Yes     2nd Dose
# ...            ...                     ...             ...          ...
# 9995  Indianapolis                  Asthma              No      Booster
# 9996  Philadelphia                Diabetes             Yes      Booster
# 9997       Seattle                  Asthma              No     2nd Dose
# 9998   Los Angeles                     NaN             Yes     2nd Dose
# 9999   San Antonio            Hypertension              No     1st Dose
#
# [10000 rows x 8 columns]

# %%
df.select_dtypes(include=["number"]).columns.difference(['User_ID'])
# Out:
# Index(['Age', 'BMI', 'Cholesterol Level', 'Outcome', 'Patient ID', 'Severity'], dtype='object')

# %%
df['Heart Attack Date'] = pd.to_datetime(df['Heart Attack Date'], errors='coerce')
df['Heart Attack Date'].apply(lambda x: 1 if x else 0)
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 9995    1
# 9996    1
# 9997    1
# 9998    1
# 9999    1
# Name: Heart Attack Date, Length: 10000, dtype: int64

# %%
df['Heart Attack Date'].notna().astype(int).sum()
# Out:
# 3060
