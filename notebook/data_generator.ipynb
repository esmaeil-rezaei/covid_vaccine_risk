# %%
import random
import csv
from pathlib import Path
from datetime import datetime, timedelta

# Predefined possible values for some fields
genders = ["Male", "Female"]
vaccination_doses = ["1st Dose", "2nd Dose", "Booster"]
conditions = ["None", "Hypertension", "Diabetes", "Heart Disease", "Asthma"]
us_locations = [
    "New York", "Los Angeles", "Chicago", "Houston", "Phoenix", 
    "Philadelphia", "San Antonio", "San Diego", "Dallas", "San Jose",
    "Austin", "Jacksonville", "Fort Worth", "Columbus", "Charlotte",
    "Indianapolis", "Seattle", "Denver", "Washington", "Boston"
]
blood_pressure_levels = ["Very Low", "Low", "Normal", "High", "Very High"]
cholesterol_levels = [180, 190, 200, 210, 220, 250, 275, 300, 350]
smoking_history = ["Yes", "No"]
diabetes_status = ["Yes", "No"]

# Helper function to generate random dates
def random_date(start_date, end_date):
    return start_date + timedelta(days=random.randint(0, (end_date - start_date).days))

# Helper function to generate random values for each field
def generate_random_data():
    # Randomly generate values for each field
    patient_id = str(random.randint(100, 999))
    age = str(random.randint(18, 90))  # Random age between 18 and 90
    gender = random.choice(genders)
    vaccination_date = random_date(datetime(2020, 1, 1), datetime(2023, 12, 31)).strftime("%Y-%m-%d")
    vaccine_dose = random.choice(vaccination_doses)
    pre_existing_conditions = random.choice(conditions)
    
    # 10% chance of having a heart attack
    heart_attack_date = ""  
    heart_attack_related_to_vaccine = False

    # 30% chance to have heart attack
    if random.random() < 0.3:  # 10% chance
        # 50% chance that the heart attack is related to vaccination
        heart_attack_related_to_vaccine = random.random() < 0.5
        
        if heart_attack_related_to_vaccine:
            # Heart attack occurs within 1-6 weeks after vaccination
            heart_attack_date = random_date(
                datetime.strptime(vaccination_date, "%Y-%m-%d"),
                datetime.strptime(vaccination_date, "%Y-%m-%d") + timedelta(weeks=6)
            ).strftime("%Y-%m-%d")
        else:
            # Random heart attack date
            heart_attack_date = random_date(datetime(2000, 1, 1), datetime(2023, 12, 31)).strftime("%Y-%m-%d")

    location = random.choice(us_locations)
    blood_pressure = random.choice(blood_pressure_levels)
    cholesterol_level = str(random.choice(cholesterol_levels))
    bmi = round(random.uniform(18.5, 40.0), 1)  # Random BMI between 18.5 and 40.0
    smoking_history_status = random.choice(smoking_history)
    diabetes_status_value = random.choice(diabetes_status)

    # Construct the random data dictionary
    random_data = {
        "Patient ID": patient_id,
        "Age": age,
        "Gender": gender,
        "Vaccination Date": vaccination_date,
        "Vaccine Dose": vaccine_dose,
        "Pre-existing Conditions": pre_existing_conditions,
        "Heart Attack Date": heart_attack_date,
        "Heart Attack Related to Vaccine": heart_attack_related_to_vaccine,
        "Location": location,
        "Blood Pressure": blood_pressure,
        "Cholesterol Level": cholesterol_level,
        "BMI": bmi,
        "Smoking History": smoking_history_status,
        "Diabetes Status": diabetes_status_value
    }

    return random_data

# Generate a list of random patient data
def generate_multiple_patients(num_patients=10000):
    patient_data_list = []
    for _ in range(num_patients):
        patient_data_list.append(generate_random_data())
    return patient_data_list

# Generate data for 10000 random patients
random_patients = generate_multiple_patients(10000)

# Define the CSV file path
csv_file_path = Path("../artifacts/data.csv")

# Define the CSV header (columns)
csv_header = [
    "Patient ID", "Age", "Gender", "Vaccination Date", "Vaccine Dose", 
    "Pre-existing Conditions", "Heart Attack Date", "Heart Attack Related to Vaccine",
    "Location", "Blood Pressure", "Cholesterol Level", "BMI", 
    "Smoking History", "Diabetes Status"
]

# Save the data to a CSV file
with open(csv_file_path, "w", newline="") as csvfile:
    csv_writer = csv.DictWriter(csvfile, fieldnames=csv_header)
    csv_writer.writeheader()  # Write the header
    csv_writer.writerows(random_patients)  # Write the patient data

print(f"10000 patient records generated with 10% heart attack condition and vaccine-heart attack relationship saved to '{csv_file_path}'")
# Out:
# 10000 patient records generated with 10% heart attack condition and vaccine-heart attack relationship saved to '../artifacts/data.csv'

# %%
random_patients
# Out:
# [{'Patient ID': '879',
#   'Age': '82',
#   'Gender': 'Male',
#   'Vaccination Date': '2022-06-06',
#   'Vaccine Dose': '2nd Dose',
#   'Pre-existing Conditions': 'Asthma',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'San Diego',
#   'Blood Pressure': 'Very Low',
#   'Cholesterol Level': '180',
#   'BMI': 35.0,
#   'Smoking History': 'No',
#   'Diabetes Status': 'Yes'},
#  {'Patient ID': '492',
#   'Age': '48',
#   'Gender': 'Female',
#   'Vaccination Date': '2020-09-11',
#   'Vaccine Dose': 'Booster',
#   'Pre-existing Conditions': 'Heart Disease',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Charlotte',
#   'Blood Pressure': 'Low',
#   'Cholesterol Level': '220',
#   'BMI': 22.5,
#   'Smoking History': 'No',
#   'Diabetes Status': 'Yes'},
#  {'Patient ID': '146',
#   'Age': '80',
#   'Gender': 'Male',
#   'Vaccination Date': '2023-02-03',
#   'Vaccine Dose': '1st Dose',
#   'Pre-existing Conditions': 'Hypertension',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'San Diego',
#   'Blood Pressure': 'Very High',
#   'Cholesterol Level': '210',
#   'BMI': 25.6,
#   'Smoking History': 'Yes',
#   'Diabetes Status': 'Yes'},
#  {'Patient ID': '739',
#   'Age': '74',
#   'Gender': 'Male',
#   'Vaccination Date': '2020-12-29',
#   'Vaccine Dose': 'Booster',
#   'Pre-existing Conditions': 'Diabetes',
#   'Heart Attack Date': '2021-01-10',
#   'Heart Attack Related to Vaccine': True,
#   'Location': 'Fort Worth',
#   'Blood Pressure': 'High',
#   'Cholesterol Level': '275',
#   'BMI': 20.8,
#   'Smoking History': 'Yes',
#   'Diabetes Status': 'No'},
#  {'Patient ID': '209',
#   'Age': '30',
#   'Gender': 'Male',
#   'Vaccination Date': '2020-05-29',
#   'Vaccine Dose': '2nd Dose',
#   'Pre-existing Conditions': 'Asthma',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'San Jose',
#   'Blood Pressure': 'High',
#   'Cholesterol Level': '200',
#   'BMI': 35.3,
#   'Smoking History': 'Yes',
#   'Diabetes Status': 'Yes'},
#  {'Patient ID': '392',
#   'Age': '43',
#   'Gender': 'Male',
#   'Vaccination Date': '2021-04-12',
#   'Vaccine Dose': 'Booster',
#   'Pre-existing Conditions': 'Hypertension',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Charlotte',
#   'Blood Pressure': 'Very Low',
#   'Cholesterol Level': '350',
#   'BMI': 33.6,
#   'Smoking History': 'Yes',
#   'Diabetes Status': 'No'},
#  {'Patient ID': '777',
#   'Age': '76',
#   'Gender': 'Female',
#   'Vaccination Date': '2021-04-16',
#   'Vaccine Dose': '2nd Dose',
#   'Pre-existing Conditions': 'Heart Disease',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Jacksonville',
#   'Blood Pressure': 'Very Low',
#   'Cholesterol Level': '300',
#   'BMI': 36.0,
#   'Smoking History': 'Yes',
#   'Diabetes Status': 'No'},
#  {'Patient ID': '706',
#   'Age': '44',
#   'Gender': 'Female',
#   'Vaccination Date': '2022-07-21',
#   'Vaccine Dose': '2nd Dose',
#   'Pre-existing Conditions': 'Heart Disease',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Philadelphia',
#   'Blood Pressure': 'Very High',
#   'Cholesterol Level': '350',
#   'BMI': 36.3,
#   'Smoking History': 'No',
#   'Diabetes Status': 'Yes'},
#  {'Patient ID': '362',
#   'Age': '76',
#   'Gender': 'Female',
#   'Vaccination Date': '2022-10-30',
#   'Vaccine Dose': '2nd Dose',
#   'Pre-existing Conditions': 'Heart Disease',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'San Diego',
#   'Blood Pressure': 'Normal',
#   'Cholesterol Level': '180',
#   'BMI': 20.4,
#   'Smoking History': 'No',
#   'Diabetes Status': 'No'},
#  {'Patient ID': '210',
#   'Age': '53',
#   'Gender': 'Male',
#   'Vaccination Date': '2020-10-26',
#   'Vaccine Dose': '2nd Dose',
#   'Pre-existing Conditions': 'Asthma',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'New York',
#   'Blood Pressure': 'Very High',
#   'Cholesterol Level': '275',
#   'BMI': 34.2,
#   'Smoking History': 'No',
#   'Diabetes Status': 'Yes'},
#  {'Patient ID': '782',
#   'Age': '68',
#   'Gender': 'Female',
#   'Vaccination Date': '2020-03-27',
#   'Vaccine Dose': '1st Dose',
#   'Pre-existing Conditions': 'Heart Disease',
#   'Heart Attack Date': '2020-04-23',
#   'Heart Attack Related to Vaccine': True,
#   'Location': 'Columbus',
#   'Blood Pressure': 'Very Low',
#   'Cholesterol Level': '220',
#   'BMI': 21.5,
#   'Smoking History': 'No',
#   'Diabetes Status': 'No'},
#  {'Patient ID': '379',
#   'Age': '77',
#   'Gender': 'Male',
#   'Vaccination Date': '2020-08-03',
#   'Vaccine Dose': '1st Dose',
#   'Pre-existing Conditions': 'Heart Disease',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Philadelphia',
#   'Blood Pressure': 'Very High',
#   'Cholesterol Level': '300',
#   'BMI': 20.6,
#   'Smoking History': 'Yes',
#   'Diabetes Status': 'No'},
#  {'Patient ID': '560',
#   'Age': '48',
#   'Gender': 'Male',
#   'Vaccination Date': '2023-11-12',
#   'Vaccine Dose': '1st Dose',
#   'Pre-existing Conditions': 'Diabetes',
#   'Heart Attack Date': '2023-12-16',
#   'Heart Attack Related to Vaccine': True,
#   'Location': 'Fort Worth',
#   'Blood Pressure': 'High',
#   'Cholesterol Level': '250',
#   'BMI': 36.0,
#   'Smoking History': 'No',
#   'Diabetes Status': 'Yes'},
#  {'Patient ID': '652',
#   'Age': '50',
#   'Gender': 'Female',
#   'Vaccination Date': '2021-06-11',
#   'Vaccine Dose': '1st Dose',
#   'Pre-existing Conditions': 'Diabetes',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'New York',
#   'Blood Pressure': 'Very Low',
#   'Cholesterol Level': '180',
#   'BMI': 28.0,
#   'Smoking History': 'Yes',
#   'Diabetes Status': 'No'},
#  {'Patient ID': '532',
#   'Age': '28',
#   'Gender': 'Female',
#   'Vaccination Date': '2023-01-29',
#   'Vaccine Dose': 'Booster',
#   'Pre-existing Conditions': 'Heart Disease',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'San Antonio',
#   'Blood Pressure': 'Very Low',
#   'Cholesterol Level': '190',
#   'BMI': 39.5,
#   'Smoking History': 'No',
#   'Diabetes Status': 'Yes'},
#  {'Patient ID': '142',
#   'Age': '71',
#   'Gender': 'Female',
#   'Vaccination Date': '2021-08-18',
#   'Vaccine Dose': 'Booster',
#   'Pre-existing Conditions': 'Diabetes',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'San Antonio',
#   'Blood Pressure': 'Very High',
#   'Cholesterol Level': '200',
#   'BMI': 31.4,
#   'Smoking History': 'No',
#   'Diabetes Status': 'Yes'},
#  {'Patient ID': '998',
#   'Age': '77',
#   'Gender': 'Female',
#   'Vaccination Date': '2022-05-11',
#   'Vaccine Dose': 'Booster',
#   'Pre-existing Conditions': 'Asthma',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Washington',
#   'Blood Pressure': 'Low',
#   'Cholesterol Level': '190',
#   'BMI': 18.9,
#   'Smoking History': 'No',
#   'Diabetes Status': 'Yes'},
#  {'Patient ID': '961',
#   'Age': '64',
#   'Gender': 'Male',
#   'Vaccination Date': '2020-03-03',
#   'Vaccine Dose': '2nd Dose',
#   'Pre-existing Conditions': 'Heart Disease',
#   'Heart Attack Date': '2011-07-05',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Denver',
#   'Blood Pressure': 'Very High',
#   'Cholesterol Level': '180',
#   'BMI': 20.8,
#   'Smoking History': 'Yes',
#   'Diabetes Status': 'Yes'},
#  {'Patient ID': '470',
#   'Age': '51',
#   'Gender': 'Female',
#   'Vaccination Date': '2023-08-06',
#   'Vaccine Dose': 'Booster',
#   'Pre-existing Conditions': 'None',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Houston',
#   'Blood Pressure': 'Very High',
#   'Cholesterol Level': '275',
#   'BMI': 19.2,
#   'Smoking History': 'Yes',
#   'Diabetes Status': 'Yes'},
#  {'Patient ID': '526',
#   'Age': '82',
#   'Gender': 'Female',
#   'Vaccination Date': '2020-11-25',
#   'Vaccine Dose': 'Booster',
#   'Pre-existing Conditions': 'Asthma',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Fort Worth',
#   'Blood Pressure': 'High',
#   'Cholesterol Level': '250',
#   'BMI': 22.9,
#   'Smoking History': 'No',
#   'Diabetes Status': 'Yes'},
#  {'Patient ID': '873',
#   'Age': '32',
#   'Gender': 'Male',
#   'Vaccination Date': '2020-07-30',
#   'Vaccine Dose': 'Booster',
#   'Pre-existing Conditions': 'Diabetes',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Charlotte',
#   'Blood Pressure': 'Normal',
#   'Cholesterol Level': '210',
#   'BMI': 36.9,
#   'Smoking History': 'Yes',
#   'Diabetes Status': 'Yes'},
#  {'Patient ID': '977',
#   'Age': '27',
#   'Gender': 'Female',
#   'Vaccination Date': '2021-09-14',
#   'Vaccine Dose': 'Booster',
#   'Pre-existing Conditions': 'Hypertension',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'San Diego',
#   'Blood Pressure': 'Very Low',
#   'Cholesterol Level': '190',
#   'BMI': 32.2,
#   'Smoking History': 'No',
#   'Diabetes Status': 'No'},
#  {'Patient ID': '650',
#   'Age': '49',
#   'Gender': 'Female',
#   'Vaccination Date': '2021-01-28',
#   'Vaccine Dose': '1st Dose',
#   'Pre-existing Conditions': 'Asthma',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Jacksonville',
#   'Blood Pressure': 'Normal',
#   'Cholesterol Level': '220',
#   'BMI': 39.6,
#   'Smoking History': 'No',
#   'Diabetes Status': 'Yes'},
#  {'Patient ID': '875',
#   'Age': '83',
#   'Gender': 'Female',
#   'Vaccination Date': '2022-03-20',
#   'Vaccine Dose': 'Booster',
#   'Pre-existing Conditions': 'Diabetes',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Boston',
#   'Blood Pressure': 'Very Low',
#   'Cholesterol Level': '210',
#   'BMI': 24.7,
#   'Smoking History': 'Yes',
#   'Diabetes Status': 'No'},
#  {'Patient ID': '947',
#   'Age': '53',
#   'Gender': 'Male',
#   'Vaccination Date': '2022-02-21',
#   'Vaccine Dose': '1st Dose',
#   'Pre-existing Conditions': 'Asthma',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Austin',
#   'Blood Pressure': 'Low',
#   'Cholesterol Level': '200',
#   'BMI': 19.4,
#   'Smoking History': 'Yes',
#   'Diabetes Status': 'No'},
#  {'Patient ID': '987',
#   'Age': '85',
#   'Gender': 'Male',
#   'Vaccination Date': '2021-02-14',
#   'Vaccine Dose': '1st Dose',
#   'Pre-existing Conditions': 'None',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Denver',
#   'Blood Pressure': 'High',
#   'Cholesterol Level': '200',
#   'BMI': 23.3,
#   'Smoking History': 'No',
#   'Diabetes Status': 'Yes'},
#  {'Patient ID': '780',
#   'Age': '67',
#   'Gender': 'Female',
#   'Vaccination Date': '2020-07-24',
#   'Vaccine Dose': '2nd Dose',
#   'Pre-existing Conditions': 'Heart Disease',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Austin',
#   'Blood Pressure': 'Very High',
#   'Cholesterol Level': '190',
#   'BMI': 21.9,
#   'Smoking History': 'Yes',
#   'Diabetes Status': 'No'},
#  {'Patient ID': '584',
#   'Age': '23',
#   'Gender': 'Male',
#   'Vaccination Date': '2023-10-14',
#   'Vaccine Dose': 'Booster',
#   'Pre-existing Conditions': 'Diabetes',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'New York',
#   'Blood Pressure': 'Very High',
#   'Cholesterol Level': '300',
#   'BMI': 32.2,
#   'Smoking History': 'Yes',
#   'Diabetes Status': 'No'},
#  {'Patient ID': '179',
#   'Age': '57',
#   'Gender': 'Female',
#   'Vaccination Date': '2020-07-12',
#   'Vaccine Dose': 'Booster',
#   'Pre-existing Conditions': 'None',
#   'Heart Attack Date': '2020-08-16',
#   'Heart Attack Related to Vaccine': True,
#   'Location': 'Washington',
#   'Blood Pressure': 'Very High',
#   'Cholesterol Level': '220',
#   'BMI': 24.2,
#   'Smoking History': 'No',
#   'Diabetes Status': 'Yes'},
#  {'Patient ID': '520',
#   'Age': '75',
#   'Gender': 'Male',
#   'Vaccination Date': '2021-06-02',
#   'Vaccine Dose': 'Booster',
#   'Pre-existing Conditions': 'Heart Disease',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'San Jose',
#   'Blood Pressure': 'Very Low',
#   'Cholesterol Level': '200',
#   'BMI': 36.8,
#   'Smoking History': 'No',
#   'Diabetes Status': 'No'},
#  {'Patient ID': '892',
#   'Age': '26',
#   'Gender': 'Female',
#   'Vaccination Date': '2022-07-05',
#   'Vaccine Dose': '1st Dose',
#   'Pre-existing Conditions': 'None',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Chicago',
#   'Blood Pressure': 'High',
#   'Cholesterol Level': '300',
#   'BMI': 24.5,
#   'Smoking History': 'Yes',
#   'Diabetes Status': 'No'},
#  {'Patient ID': '255',
#   'Age': '25',
#   'Gender': 'Female',
#   'Vaccination Date': '2021-12-02',
#   'Vaccine Dose': '2nd Dose',
#   'Pre-existing Conditions': 'Asthma',
#   'Heart Attack Date': '2021-12-23',
#   'Heart Attack Related to Vaccine': True,
#   'Location': 'San Antonio',
#   'Blood Pressure': 'Very High',
#   'Cholesterol Level': '220',
#   'BMI': 35.6,
#   'Smoking History': 'No',
#   'Diabetes Status': 'No'},
#  {'Patient ID': '244',
#   'Age': '32',
#   'Gender': 'Male',
#   'Vaccination Date': '2021-07-12',
#   'Vaccine Dose': '2nd Dose',
#   'Pre-existing Conditions': 'Diabetes',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Fort Worth',
#   'Blood Pressure': 'Very Low',
#   'Cholesterol Level': '190',
#   'BMI': 32.3,
#   'Smoking History': 'No',
#   'Diabetes Status': 'Yes'},
#  {'Patient ID': '766',
#   'Age': '49',
#   'Gender': 'Male',
#   'Vaccination Date': '2022-07-31',
#   'Vaccine Dose': '1st Dose',
#   'Pre-existing Conditions': 'None',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Columbus',
#   'Blood Pressure': 'High',
#   'Cholesterol Level': '300',
#   'BMI': 19.9,
#   'Smoking History': 'No',
#   'Diabetes Status': 'No'},
#  {'Patient ID': '314',
#   'Age': '90',
#   'Gender': 'Male',
#   'Vaccination Date': '2023-04-20',
#   'Vaccine Dose': '2nd Dose',
#   'Pre-existing Conditions': 'Hypertension',
#   'Heart Attack Date': '2023-04-14',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Los Angeles',
#   'Blood Pressure': 'Very High',
#   'Cholesterol Level': '275',
#   'BMI': 23.6,
#   'Smoking History': 'No',
#   'Diabetes Status': 'No'},
#  {'Patient ID': '431',
#   'Age': '29',
#   'Gender': 'Female',
#   'Vaccination Date': '2021-11-14',
#   'Vaccine Dose': '2nd Dose',
#   'Pre-existing Conditions': 'Heart Disease',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Jacksonville',
#   'Blood Pressure': 'Very High',
#   'Cholesterol Level': '220',
#   'BMI': 34.4,
#   'Smoking History': 'Yes',
#   'Diabetes Status': 'Yes'},
#  {'Patient ID': '962',
#   'Age': '24',
#   'Gender': 'Female',
#   'Vaccination Date': '2021-04-03',
#   'Vaccine Dose': '1st Dose',
#   'Pre-existing Conditions': 'None',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'San Jose',
#   'Blood Pressure': 'Normal',
#   'Cholesterol Level': '350',
#   'BMI': 19.9,
#   'Smoking History': 'Yes',
#   'Diabetes Status': 'Yes'},
#  {'Patient ID': '665',
#   'Age': '47',
#   'Gender': 'Male',
#   'Vaccination Date': '2021-11-29',
#   'Vaccine Dose': '1st Dose',
#   'Pre-existing Conditions': 'None',
#   'Heart Attack Date': '2023-01-01',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Dallas',
#   'Blood Pressure': 'High',
#   'Cholesterol Level': '220',
#   'BMI': 35.5,
#   'Smoking History': 'No',
#   'Diabetes Status': 'No'},
#  {'Patient ID': '321',
#   'Age': '36',
#   'Gender': 'Male',
#   'Vaccination Date': '2022-05-15',
#   'Vaccine Dose': 'Booster',
#   'Pre-existing Conditions': 'Diabetes',
#   'Heart Attack Date': '2019-11-30',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Los Angeles',
#   'Blood Pressure': 'Normal',
#   'Cholesterol Level': '180',
#   'BMI': 31.0,
#   'Smoking History': 'Yes',
#   'Diabetes Status': 'Yes'},
#  {'Patient ID': '801',
#   'Age': '83',
#   'Gender': 'Female',
#   'Vaccination Date': '2022-04-27',
#   'Vaccine Dose': '1st Dose',
#   'Pre-existing Conditions': 'Diabetes',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Charlotte',
#   'Blood Pressure': 'Normal',
#   'Cholesterol Level': '350',
#   'BMI': 24.1,
#   'Smoking History': 'No',
#   'Diabetes Status': 'No'},
#  {'Patient ID': '799',
#   'Age': '85',
#   'Gender': 'Female',
#   'Vaccination Date': '2022-07-07',
#   'Vaccine Dose': '2nd Dose',
#   'Pre-existing Conditions': 'Hypertension',
#   'Heart Attack Date': '2017-02-14',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Austin',
#   'Blood Pressure': 'Very Low',
#   'Cholesterol Level': '300',
#   'BMI': 34.5,
#   'Smoking History': 'No',
#   'Diabetes Status': 'Yes'},
#  {'Patient ID': '468',
#   'Age': '64',
#   'Gender': 'Female',
#   'Vaccination Date': '2022-05-12',
#   'Vaccine Dose': 'Booster',
#   'Pre-existing Conditions': 'None',
#   'Heart Attack Date': '2022-06-09',
#   'Heart Attack Related to Vaccine': True,
#   'Location': 'Dallas',
#   'Blood Pressure': 'High',
#   'Cholesterol Level': '220',
#   'BMI': 37.5,
#   'Smoking History': 'No',
#   'Diabetes Status': 'Yes'},
#  {'Patient ID': '498',
#   'Age': '79',
#   'Gender': 'Male',
#   'Vaccination Date': '2020-11-22',
#   'Vaccine Dose': '2nd Dose',
#   'Pre-existing Conditions': 'Asthma',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Jacksonville',
#   'Blood Pressure': 'Very High',
#   'Cholesterol Level': '250',
#   'BMI': 38.0,
#   'Smoking History': 'No',
#   'Diabetes Status': 'Yes'},
#  {'Patient ID': '414',
#   'Age': '37',
#   'Gender': 'Male',
#   'Vaccination Date': '2023-02-17',
#   'Vaccine Dose': '2nd Dose',
#   'Pre-existing Conditions': 'None',
#   'Heart Attack Date': '2023-03-13',
#   'Heart Attack Related to Vaccine': True,
#   'Location': 'Seattle',
#   'Blood Pressure': 'Very High',
#   'Cholesterol Level': '220',
#   'BMI': 24.1,
#   'Smoking History': 'Yes',
#   'Diabetes Status': 'No'},
#  {'Patient ID': '629',
#   'Age': '76',
#   'Gender': 'Female',
#   'Vaccination Date': '2022-08-11',
#   'Vaccine Dose': '1st Dose',
#   'Pre-existing Conditions': 'Diabetes',
#   'Heart Attack Date': '2006-05-27',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Fort Worth',
#   'Blood Pressure': 'Normal',
#   'Cholesterol Level': '250',
#   'BMI': 27.0,
#   'Smoking History': 'Yes',
#   'Diabetes Status': 'Yes'},
#  {'Patient ID': '583',
#   'Age': '33',
#   'Gender': 'Male',
#   'Vaccination Date': '2020-07-01',
#   'Vaccine Dose': '2nd Dose',
#   'Pre-existing Conditions': 'Heart Disease',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Dallas',
#   'Blood Pressure': 'Very Low',
#   'Cholesterol Level': '180',
#   'BMI': 35.9,
#   'Smoking History': 'Yes',
#   'Diabetes Status': 'Yes'},
#  {'Patient ID': '833',
#   'Age': '68',
#   'Gender': 'Female',
#   'Vaccination Date': '2020-06-10',
#   'Vaccine Dose': 'Booster',
#   'Pre-existing Conditions': 'Heart Disease',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Denver',
#   'Blood Pressure': 'High',
#   'Cholesterol Level': '190',
#   'BMI': 37.4,
#   'Smoking History': 'No',
#   'Diabetes Status': 'No'},
#  {'Patient ID': '826',
#   'Age': '90',
#   'Gender': 'Female',
#   'Vaccination Date': '2022-04-11',
#   'Vaccine Dose': '1st Dose',
#   'Pre-existing Conditions': 'Hypertension',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Washington',
#   'Blood Pressure': 'Low',
#   'Cholesterol Level': '190',
#   'BMI': 27.1,
#   'Smoking History': 'Yes',
#   'Diabetes Status': 'Yes'},
#  {'Patient ID': '559',
#   'Age': '47',
#   'Gender': 'Male',
#   'Vaccination Date': '2020-04-17',
#   'Vaccine Dose': '1st Dose',
#   'Pre-existing Conditions': 'Hypertension',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'San Diego',
#   'Blood Pressure': 'Very Low',
#   'Cholesterol Level': '250',
#   'BMI': 25.0,
#   'Smoking History': 'Yes',
#   'Diabetes Status': 'No'},
#  {'Patient ID': '280',
#   'Age': '18',
#   'Gender': 'Male',
#   'Vaccination Date': '2022-06-14',
#   'Vaccine Dose': '1st Dose',
#   'Pre-existing Conditions': 'Heart Disease',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Denver',
#   'Blood Pressure': 'High',
#   'Cholesterol Level': '275',
#   'BMI': 30.2,
#   'Smoking History': 'Yes',
#   'Diabetes Status': 'Yes'},
#  {'Patient ID': '478',
#   'Age': '49',
#   'Gender': 'Female',
#   'Vaccination Date': '2021-04-16',
#   'Vaccine Dose': '1st Dose',
#   'Pre-existing Conditions': 'Asthma',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'San Diego',
#   'Blood Pressure': 'Very High',
#   'Cholesterol Level': '200',
#   'BMI': 24.6,
#   'Smoking History': 'No',
#   'Diabetes Status': 'No'},
#  {'Patient ID': '370',
#   'Age': '72',
#   'Gender': 'Male',
#   'Vaccination Date': '2023-03-30',
#   'Vaccine Dose': '2nd Dose',
#   'Pre-existing Conditions': 'Hypertension',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Houston',
#   'Blood Pressure': 'Very High',
#   'Cholesterol Level': '250',
#   'BMI': 20.7,
#   'Smoking History': 'No',
#   'Diabetes Status': 'No'},
#  {'Patient ID': '490',
#   'Age': '35',
#   'Gender': 'Female',
#   'Vaccination Date': '2022-12-13',
#   'Vaccine Dose': '1st Dose',
#   'Pre-existing Conditions': 'Heart Disease',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Jacksonville',
#   'Blood Pressure': 'High',
#   'Cholesterol Level': '180',
#   'BMI': 22.6,
#   'Smoking History': 'No',
#   'Diabetes Status': 'Yes'},
#  {'Patient ID': '557',
#   'Age': '26',
#   'Gender': 'Male',
#   'Vaccination Date': '2020-08-30',
#   'Vaccine Dose': '1st Dose',
#   'Pre-existing Conditions': 'Diabetes',
#   'Heart Attack Date': '2020-09-27',
#   'Heart Attack Related to Vaccine': True,
#   'Location': 'Fort Worth',
#   'Blood Pressure': 'Very Low',
#   'Cholesterol Level': '180',
#   'BMI': 37.1,
#   'Smoking History': 'No',
#   'Diabetes Status': 'Yes'},
#  {'Patient ID': '125',
#   'Age': '34',
#   'Gender': 'Male',
#   'Vaccination Date': '2022-07-31',
#   'Vaccine Dose': '2nd Dose',
#   'Pre-existing Conditions': 'None',
#   'Heart Attack Date': '2022-07-31',
#   'Heart Attack Related to Vaccine': True,
#   'Location': 'Seattle',
#   'Blood Pressure': 'Normal',
#   'Cholesterol Level': '300',
#   'BMI': 27.9,
#   'Smoking History': 'No',
#   'Diabetes Status': 'No'},
#  {'Patient ID': '621',
#   'Age': '51',
#   'Gender': 'Male',
#   'Vaccination Date': '2022-08-20',
#   'Vaccine Dose': 'Booster',
#   'Pre-existing Conditions': 'Heart Disease',
#   'Heart Attack Date': '2022-07-09',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Charlotte',
#   'Blood Pressure': 'High',
#   'Cholesterol Level': '190',
#   'BMI': 23.8,
#   'Smoking History': 'No',
#   'Diabetes Status': 'Yes'},
#  {'Patient ID': '986',
#   'Age': '40',
#   'Gender': 'Male',
#   'Vaccination Date': '2022-06-24',
#   'Vaccine Dose': 'Booster',
#   'Pre-existing Conditions': 'None',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Denver',
#   'Blood Pressure': 'Very Low',
#   'Cholesterol Level': '350',
#   'BMI': 33.8,
#   'Smoking History': 'Yes',
#   'Diabetes Status': 'No'},
#  {'Patient ID': '459',
#   'Age': '77',
#   'Gender': 'Female',
#   'Vaccination Date': '2023-03-19',
#   'Vaccine Dose': 'Booster',
#   'Pre-existing Conditions': 'Heart Disease',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Jacksonville',
#   'Blood Pressure': 'Normal',
#   'Cholesterol Level': '180',
#   'BMI': 37.2,
#   'Smoking History': 'Yes',
#   'Diabetes Status': 'No'},
#  {'Patient ID': '311',
#   'Age': '43',
#   'Gender': 'Female',
#   'Vaccination Date': '2022-11-20',
#   'Vaccine Dose': '1st Dose',
#   'Pre-existing Conditions': 'Heart Disease',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Charlotte',
#   'Blood Pressure': 'Low',
#   'Cholesterol Level': '190',
#   'BMI': 20.0,
#   'Smoking History': 'Yes',
#   'Diabetes Status': 'No'},
#  {'Patient ID': '858',
#   'Age': '56',
#   'Gender': 'Male',
#   'Vaccination Date': '2023-05-07',
#   'Vaccine Dose': '2nd Dose',
#   'Pre-existing Conditions': 'Heart Disease',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Jacksonville',
#   'Blood Pressure': 'Very Low',
#   'Cholesterol Level': '300',
#   'BMI': 30.3,
#   'Smoking History': 'Yes',
#   'Diabetes Status': 'Yes'},
#  {'Patient ID': '511',
#   'Age': '40',
#   'Gender': 'Male',
#   'Vaccination Date': '2023-05-01',
#   'Vaccine Dose': 'Booster',
#   'Pre-existing Conditions': 'Hypertension',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Boston',
#   'Blood Pressure': 'Very Low',
#   'Cholesterol Level': '250',
#   'BMI': 29.5,
#   'Smoking History': 'Yes',
#   'Diabetes Status': 'Yes'},
#  {'Patient ID': '788',
#   'Age': '47',
#   'Gender': 'Female',
#   'Vaccination Date': '2022-09-12',
#   'Vaccine Dose': '2nd Dose',
#   'Pre-existing Conditions': 'Hypertension',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'San Jose',
#   'Blood Pressure': 'High',
#   'Cholesterol Level': '350',
#   'BMI': 23.2,
#   'Smoking History': 'No',
#   'Diabetes Status': 'No'},
#  {'Patient ID': '793',
#   'Age': '28',
#   'Gender': 'Female',
#   'Vaccination Date': '2021-04-03',
#   'Vaccine Dose': '1st Dose',
#   'Pre-existing Conditions': 'Diabetes',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Dallas',
#   'Blood Pressure': 'Normal',
#   'Cholesterol Level': '350',
#   'BMI': 27.1,
#   'Smoking History': 'No',
#   'Diabetes Status': 'No'},
#  {'Patient ID': '277',
#   'Age': '20',
#   'Gender': 'Female',
#   'Vaccination Date': '2021-01-14',
#   'Vaccine Dose': '1st Dose',
#   'Pre-existing Conditions': 'Hypertension',
#   'Heart Attack Date': '2021-02-07',
#   'Heart Attack Related to Vaccine': True,
#   'Location': 'Jacksonville',
#   'Blood Pressure': 'Very Low',
#   'Cholesterol Level': '210',
#   'BMI': 19.9,
#   'Smoking History': 'Yes',
#   'Diabetes Status': 'No'},
#  {'Patient ID': '823',
#   'Age': '80',
#   'Gender': 'Male',
#   'Vaccination Date': '2022-01-27',
#   'Vaccine Dose': '1st Dose',
#   'Pre-existing Conditions': 'Diabetes',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Charlotte',
#   'Blood Pressure': 'Very Low',
#   'Cholesterol Level': '300',
#   'BMI': 20.3,
#   'Smoking History': 'Yes',
#   'Diabetes Status': 'No'},
#  {'Patient ID': '324',
#   'Age': '19',
#   'Gender': 'Male',
#   'Vaccination Date': '2020-06-06',
#   'Vaccine Dose': '2nd Dose',
#   'Pre-existing Conditions': 'Heart Disease',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Washington',
#   'Blood Pressure': 'Very Low',
#   'Cholesterol Level': '190',
#   'BMI': 24.5,
#   'Smoking History': 'Yes',
#   'Diabetes Status': 'No'},
#  {'Patient ID': '497',
#   'Age': '43',
#   'Gender': 'Male',
#   'Vaccination Date': '2021-07-13',
#   'Vaccine Dose': 'Booster',
#   'Pre-existing Conditions': 'Asthma',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Fort Worth',
#   'Blood Pressure': 'Very Low',
#   'Cholesterol Level': '210',
#   'BMI': 24.0,
#   'Smoking History': 'No',
#   'Diabetes Status': 'Yes'},
#  {'Patient ID': '558',
#   'Age': '68',
#   'Gender': 'Male',
#   'Vaccination Date': '2022-12-16',
#   'Vaccine Dose': '2nd Dose',
#   'Pre-existing Conditions': 'Asthma',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Charlotte',
#   'Blood Pressure': 'High',
#   'Cholesterol Level': '190',
#   'BMI': 25.8,
#   'Smoking History': 'No',
#   'Diabetes Status': 'Yes'},
#  {'Patient ID': '744',
#   'Age': '25',
#   'Gender': 'Male',
#   'Vaccination Date': '2021-11-14',
#   'Vaccine Dose': '1st Dose',
#   'Pre-existing Conditions': 'Hypertension',
#   'Heart Attack Date': '2007-04-11',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Charlotte',
#   'Blood Pressure': 'Very Low',
#   'Cholesterol Level': '350',
#   'BMI': 22.9,
#   'Smoking History': 'No',
#   'Diabetes Status': 'Yes'},
#  {'Patient ID': '782',
#   'Age': '83',
#   'Gender': 'Female',
#   'Vaccination Date': '2021-11-16',
#   'Vaccine Dose': '1st Dose',
#   'Pre-existing Conditions': 'Diabetes',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Denver',
#   'Blood Pressure': 'High',
#   'Cholesterol Level': '250',
#   'BMI': 24.3,
#   'Smoking History': 'No',
#   'Diabetes Status': 'Yes'},
#  {'Patient ID': '630',
#   'Age': '48',
#   'Gender': 'Male',
#   'Vaccination Date': '2022-02-16',
#   'Vaccine Dose': '2nd Dose',
#   'Pre-existing Conditions': 'Diabetes',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Fort Worth',
#   'Blood Pressure': 'Normal',
#   'Cholesterol Level': '200',
#   'BMI': 19.0,
#   'Smoking History': 'No',
#   'Diabetes Status': 'Yes'},
#  {'Patient ID': '440',
#   'Age': '75',
#   'Gender': 'Male',
#   'Vaccination Date': '2021-08-27',
#   'Vaccine Dose': '2nd Dose',
#   'Pre-existing Conditions': 'Heart Disease',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Houston',
#   'Blood Pressure': 'Very High',
#   'Cholesterol Level': '200',
#   'BMI': 32.4,
#   'Smoking History': 'No',
#   'Diabetes Status': 'Yes'},
#  {'Patient ID': '771',
#   'Age': '43',
#   'Gender': 'Female',
#   'Vaccination Date': '2020-12-20',
#   'Vaccine Dose': '1st Dose',
#   'Pre-existing Conditions': 'None',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'San Jose',
#   'Blood Pressure': 'Normal',
#   'Cholesterol Level': '300',
#   'BMI': 35.8,
#   'Smoking History': 'No',
#   'Diabetes Status': 'Yes'},
#  {'Patient ID': '630',
#   'Age': '62',
#   'Gender': 'Female',
#   'Vaccination Date': '2020-11-30',
#   'Vaccine Dose': 'Booster',
#   'Pre-existing Conditions': 'Asthma',
#   'Heart Attack Date': '2020-12-29',
#   'Heart Attack Related to Vaccine': True,
#   'Location': 'Columbus',
#   'Blood Pressure': 'High',
#   'Cholesterol Level': '190',
#   'BMI': 19.6,
#   'Smoking History': 'Yes',
#   'Diabetes Status': 'No'},
#  {'Patient ID': '792',
#   'Age': '27',
#   'Gender': 'Female',
#   'Vaccination Date': '2023-07-05',
#   'Vaccine Dose': 'Booster',
#   'Pre-existing Conditions': 'None',
#   'Heart Attack Date': '2023-07-30',
#   'Heart Attack Related to Vaccine': True,
#   'Location': 'Indianapolis',
#   'Blood Pressure': 'Very High',
#   'Cholesterol Level': '200',
#   'BMI': 33.0,
#   'Smoking History': 'Yes',
#   'Diabetes Status': 'No'},
#  {'Patient ID': '745',
#   'Age': '83',
#   'Gender': 'Male',
#   'Vaccination Date': '2023-07-07',
#   'Vaccine Dose': '2nd Dose',
#   'Pre-existing Conditions': 'None',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Los Angeles',
#   'Blood Pressure': 'Low',
#   'Cholesterol Level': '220',
#   'BMI': 22.2,
#   'Smoking History': 'No',
#   'Diabetes Status': 'Yes'},
#  {'Patient ID': '975',
#   'Age': '84',
#   'Gender': 'Female',
#   'Vaccination Date': '2022-03-22',
#   'Vaccine Dose': '2nd Dose',
#   'Pre-existing Conditions': 'None',
#   'Heart Attack Date': '2022-04-22',
#   'Heart Attack Related to Vaccine': True,
#   'Location': 'Jacksonville',
#   'Blood Pressure': 'Very Low',
#   'Cholesterol Level': '300',
#   'BMI': 27.4,
#   'Smoking History': 'No',
#   'Diabetes Status': 'Yes'},
#  {'Patient ID': '687',
#   'Age': '35',
#   'Gender': 'Male',
#   'Vaccination Date': '2021-10-06',
#   'Vaccine Dose': '2nd Dose',
#   'Pre-existing Conditions': 'None',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Chicago',
#   'Blood Pressure': 'Normal',
#   'Cholesterol Level': '200',
#   'BMI': 37.4,
#   'Smoking History': 'No',
#   'Diabetes Status': 'Yes'},
#  {'Patient ID': '195',
#   'Age': '23',
#   'Gender': 'Female',
#   'Vaccination Date': '2023-03-14',
#   'Vaccine Dose': '1st Dose',
#   'Pre-existing Conditions': 'Heart Disease',
#   'Heart Attack Date': '2023-03-29',
#   'Heart Attack Related to Vaccine': True,
#   'Location': 'Charlotte',
#   'Blood Pressure': 'Very High',
#   'Cholesterol Level': '350',
#   'BMI': 33.9,
#   'Smoking History': 'Yes',
#   'Diabetes Status': 'No'},
#  {'Patient ID': '503',
#   'Age': '53',
#   'Gender': 'Female',
#   'Vaccination Date': '2022-02-05',
#   'Vaccine Dose': '2nd Dose',
#   'Pre-existing Conditions': 'Hypertension',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Chicago',
#   'Blood Pressure': 'Very High',
#   'Cholesterol Level': '180',
#   'BMI': 38.0,
#   'Smoking History': 'Yes',
#   'Diabetes Status': 'No'},
#  {'Patient ID': '410',
#   'Age': '39',
#   'Gender': 'Female',
#   'Vaccination Date': '2022-02-02',
#   'Vaccine Dose': 'Booster',
#   'Pre-existing Conditions': 'Heart Disease',
#   'Heart Attack Date': '2017-01-02',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Los Angeles',
#   'Blood Pressure': 'Normal',
#   'Cholesterol Level': '200',
#   'BMI': 20.9,
#   'Smoking History': 'No',
#   'Diabetes Status': 'Yes'},
#  {'Patient ID': '328',
#   'Age': '31',
#   'Gender': 'Female',
#   'Vaccination Date': '2021-09-01',
#   'Vaccine Dose': '2nd Dose',
#   'Pre-existing Conditions': 'Diabetes',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Phoenix',
#   'Blood Pressure': 'High',
#   'Cholesterol Level': '300',
#   'BMI': 19.0,
#   'Smoking History': 'Yes',
#   'Diabetes Status': 'No'},
#  {'Patient ID': '821',
#   'Age': '45',
#   'Gender': 'Male',
#   'Vaccination Date': '2021-02-15',
#   'Vaccine Dose': '1st Dose',
#   'Pre-existing Conditions': 'Hypertension',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Denver',
#   'Blood Pressure': 'High',
#   'Cholesterol Level': '300',
#   'BMI': 21.6,
#   'Smoking History': 'No',
#   'Diabetes Status': 'No'},
#  {'Patient ID': '339',
#   'Age': '72',
#   'Gender': 'Male',
#   'Vaccination Date': '2021-09-01',
#   'Vaccine Dose': 'Booster',
#   'Pre-existing Conditions': 'Asthma',
#   'Heart Attack Date': '2021-09-12',
#   'Heart Attack Related to Vaccine': True,
#   'Location': 'San Antonio',
#   'Blood Pressure': 'High',
#   'Cholesterol Level': '220',
#   'BMI': 31.5,
#   'Smoking History': 'No',
#   'Diabetes Status': 'Yes'},
#  {'Patient ID': '218',
#   'Age': '81',
#   'Gender': 'Male',
#   'Vaccination Date': '2020-09-09',
#   'Vaccine Dose': '1st Dose',
#   'Pre-existing Conditions': 'None',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Dallas',
#   'Blood Pressure': 'Very Low',
#   'Cholesterol Level': '220',
#   'BMI': 34.6,
#   'Smoking History': 'Yes',
#   'Diabetes Status': 'Yes'},
#  {'Patient ID': '385',
#   'Age': '38',
#   'Gender': 'Male',
#   'Vaccination Date': '2021-10-12',
#   'Vaccine Dose': '1st Dose',
#   'Pre-existing Conditions': 'Heart Disease',
#   'Heart Attack Date': '2023-08-12',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Chicago',
#   'Blood Pressure': 'Very Low',
#   'Cholesterol Level': '190',
#   'BMI': 37.8,
#   'Smoking History': 'No',
#   'Diabetes Status': 'Yes'},
#  {'Patient ID': '275',
#   'Age': '25',
#   'Gender': 'Female',
#   'Vaccination Date': '2020-01-26',
#   'Vaccine Dose': '2nd Dose',
#   'Pre-existing Conditions': 'Hypertension',
#   'Heart Attack Date': '2020-02-16',
#   'Heart Attack Related to Vaccine': True,
#   'Location': 'Los Angeles',
#   'Blood Pressure': 'Very Low',
#   'Cholesterol Level': '275',
#   'BMI': 23.8,
#   'Smoking History': 'Yes',
#   'Diabetes Status': 'Yes'},
#  {'Patient ID': '747',
#   'Age': '66',
#   'Gender': 'Female',
#   'Vaccination Date': '2020-10-21',
#   'Vaccine Dose': 'Booster',
#   'Pre-existing Conditions': 'Asthma',
#   'Heart Attack Date': '2014-08-25',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Seattle',
#   'Blood Pressure': 'Low',
#   'Cholesterol Level': '190',
#   'BMI': 39.9,
#   'Smoking History': 'Yes',
#   'Diabetes Status': 'No'},
#  {'Patient ID': '252',
#   'Age': '25',
#   'Gender': 'Male',
#   'Vaccination Date': '2020-03-17',
#   'Vaccine Dose': '2nd Dose',
#   'Pre-existing Conditions': 'Heart Disease',
#   'Heart Attack Date': '2020-04-18',
#   'Heart Attack Related to Vaccine': True,
#   'Location': 'Dallas',
#   'Blood Pressure': 'Low',
#   'Cholesterol Level': '210',
#   'BMI': 32.4,
#   'Smoking History': 'No',
#   'Diabetes Status': 'No'},
#  {'Patient ID': '177',
#   'Age': '32',
#   'Gender': 'Male',
#   'Vaccination Date': '2021-12-16',
#   'Vaccine Dose': 'Booster',
#   'Pre-existing Conditions': 'Hypertension',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Seattle',
#   'Blood Pressure': 'Low',
#   'Cholesterol Level': '275',
#   'BMI': 21.7,
#   'Smoking History': 'Yes',
#   'Diabetes Status': 'No'},
#  {'Patient ID': '716',
#   'Age': '70',
#   'Gender': 'Male',
#   'Vaccination Date': '2021-03-26',
#   'Vaccine Dose': '1st Dose',
#   'Pre-existing Conditions': 'Diabetes',
#   'Heart Attack Date': '2010-03-14',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Charlotte',
#   'Blood Pressure': 'Very Low',
#   'Cholesterol Level': '250',
#   'BMI': 19.4,
#   'Smoking History': 'No',
#   'Diabetes Status': 'No'},
#  {'Patient ID': '880',
#   'Age': '39',
#   'Gender': 'Female',
#   'Vaccination Date': '2020-11-01',
#   'Vaccine Dose': '2nd Dose',
#   'Pre-existing Conditions': 'None',
#   'Heart Attack Date': '2020-11-05',
#   'Heart Attack Related to Vaccine': True,
#   'Location': 'Philadelphia',
#   'Blood Pressure': 'Low',
#   'Cholesterol Level': '190',
#   'BMI': 25.6,
#   'Smoking History': 'Yes',
#   'Diabetes Status': 'Yes'},
#  {'Patient ID': '910',
#   'Age': '90',
#   'Gender': 'Female',
#   'Vaccination Date': '2020-02-29',
#   'Vaccine Dose': '2nd Dose',
#   'Pre-existing Conditions': 'Heart Disease',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'San Diego',
#   'Blood Pressure': 'High',
#   'Cholesterol Level': '250',
#   'BMI': 37.9,
#   'Smoking History': 'Yes',
#   'Diabetes Status': 'Yes'},
#  {'Patient ID': '928',
#   'Age': '83',
#   'Gender': 'Female',
#   'Vaccination Date': '2023-05-17',
#   'Vaccine Dose': '1st Dose',
#   'Pre-existing Conditions': 'Heart Disease',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Washington',
#   'Blood Pressure': 'Very High',
#   'Cholesterol Level': '300',
#   'BMI': 18.6,
#   'Smoking History': 'No',
#   'Diabetes Status': 'No'},
#  {'Patient ID': '102',
#   'Age': '35',
#   'Gender': 'Female',
#   'Vaccination Date': '2023-06-24',
#   'Vaccine Dose': '2nd Dose',
#   'Pre-existing Conditions': 'Asthma',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Houston',
#   'Blood Pressure': 'Normal',
#   'Cholesterol Level': '350',
#   'BMI': 20.5,
#   'Smoking History': 'No',
#   'Diabetes Status': 'Yes'},
#  {'Patient ID': '520',
#   'Age': '46',
#   'Gender': 'Male',
#   'Vaccination Date': '2022-12-11',
#   'Vaccine Dose': '1st Dose',
#   'Pre-existing Conditions': 'Asthma',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Seattle',
#   'Blood Pressure': 'Very High',
#   'Cholesterol Level': '200',
#   'BMI': 31.5,
#   'Smoking History': 'No',
#   'Diabetes Status': 'Yes'},
#  {'Patient ID': '213',
#   'Age': '84',
#   'Gender': 'Female',
#   'Vaccination Date': '2023-03-31',
#   'Vaccine Dose': 'Booster',
#   'Pre-existing Conditions': 'Diabetes',
#   'Heart Attack Date': '2006-01-15',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Charlotte',
#   'Blood Pressure': 'Very Low',
#   'Cholesterol Level': '250',
#   'BMI': 33.5,
#   'Smoking History': 'No',
#   'Diabetes Status': 'Yes'},
#  {'Patient ID': '247',
#   'Age': '79',
#   'Gender': 'Female',
#   'Vaccination Date': '2022-09-26',
#   'Vaccine Dose': '2nd Dose',
#   'Pre-existing Conditions': 'Asthma',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Philadelphia',
#   'Blood Pressure': 'Low',
#   'Cholesterol Level': '190',
#   'BMI': 32.2,
#   'Smoking History': 'No',
#   'Diabetes Status': 'Yes'},
#  {'Patient ID': '905',
#   'Age': '40',
#   'Gender': 'Female',
#   'Vaccination Date': '2021-11-03',
#   'Vaccine Dose': '1st Dose',
#   'Pre-existing Conditions': 'Diabetes',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Indianapolis',
#   'Blood Pressure': 'Very Low',
#   'Cholesterol Level': '190',
#   'BMI': 26.8,
#   'Smoking History': 'Yes',
#   'Diabetes Status': 'Yes'},
#  {'Patient ID': '246',
#   'Age': '59',
#   'Gender': 'Female',
#   'Vaccination Date': '2021-02-27',
#   'Vaccine Dose': 'Booster',
#   'Pre-existing Conditions': 'Asthma',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Seattle',
#   'Blood Pressure': 'Very High',
#   'Cholesterol Level': '220',
#   'BMI': 26.9,
#   'Smoking History': 'No',
#   'Diabetes Status': 'Yes'},
#  {'Patient ID': '400',
#   'Age': '53',
#   'Gender': 'Male',
#   'Vaccination Date': '2023-02-02',
#   'Vaccine Dose': '1st Dose',
#   'Pre-existing Conditions': 'Diabetes',
#   'Heart Attack Date': '2023-02-05',
#   'Heart Attack Related to Vaccine': True,
#   'Location': 'San Diego',
#   'Blood Pressure': 'Very Low',
#   'Cholesterol Level': '350',
#   'BMI': 35.2,
#   'Smoking History': 'No',
#   'Diabetes Status': 'No'},
#  {'Patient ID': '357',
#   'Age': '73',
#   'Gender': 'Female',
#   'Vaccination Date': '2020-11-10',
#   'Vaccine Dose': '1st Dose',
#   'Pre-existing Conditions': 'Diabetes',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'San Diego',
#   'Blood Pressure': 'Low',
#   'Cholesterol Level': '180',
#   'BMI': 38.1,
#   'Smoking History': 'Yes',
#   'Diabetes Status': 'No'},
#  {'Patient ID': '294',
#   'Age': '37',
#   'Gender': 'Female',
#   'Vaccination Date': '2022-04-21',
#   'Vaccine Dose': 'Booster',
#   'Pre-existing Conditions': 'Hypertension',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Austin',
#   'Blood Pressure': 'Low',
#   'Cholesterol Level': '350',
#   'BMI': 34.0,
#   'Smoking History': 'No',
#   'Diabetes Status': 'No'},
#  {'Patient ID': '984',
#   'Age': '69',
#   'Gender': 'Female',
#   'Vaccination Date': '2023-04-11',
#   'Vaccine Dose': '2nd Dose',
#   'Pre-existing Conditions': 'None',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Boston',
#   'Blood Pressure': 'Very Low',
#   'Cholesterol Level': '210',
#   'BMI': 30.1,
#   'Smoking History': 'Yes',
#   'Diabetes Status': 'No'},
#  {'Patient ID': '821',
#   'Age': '51',
#   'Gender': 'Male',
#   'Vaccination Date': '2020-02-09',
#   'Vaccine Dose': 'Booster',
#   'Pre-existing Conditions': 'Hypertension',
#   'Heart Attack Date': '2020-03-04',
#   'Heart Attack Related to Vaccine': True,
#   'Location': 'Los Angeles',
#   'Blood Pressure': 'Very Low',
#   'Cholesterol Level': '275',
#   'BMI': 29.8,
#   'Smoking History': 'Yes',
#   'Diabetes Status': 'Yes'},
#  {'Patient ID': '374',
#   'Age': '41',
#   'Gender': 'Male',
#   'Vaccination Date': '2022-08-01',
#   'Vaccine Dose': '1st Dose',
#   'Pre-existing Conditions': 'Heart Disease',
#   'Heart Attack Date': '2014-05-09',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Los Angeles',
#   'Blood Pressure': 'Normal',
#   'Cholesterol Level': '210',
#   'BMI': 30.2,
#   'Smoking History': 'Yes',
#   'Diabetes Status': 'No'},
#  {'Patient ID': '908',
#   'Age': '86',
#   'Gender': 'Male',
#   'Vaccination Date': '2022-08-11',
#   'Vaccine Dose': '1st Dose',
#   'Pre-existing Conditions': 'Diabetes',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Chicago',
#   'Blood Pressure': 'Normal',
#   'Cholesterol Level': '180',
#   'BMI': 37.8,
#   'Smoking History': 'Yes',
#   'Diabetes Status': 'Yes'},
#  {'Patient ID': '153',
#   'Age': '58',
#   'Gender': 'Male',
#   'Vaccination Date': '2021-03-12',
#   'Vaccine Dose': '1st Dose',
#   'Pre-existing Conditions': 'Heart Disease',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Chicago',
#   'Blood Pressure': 'Very Low',
#   'Cholesterol Level': '210',
#   'BMI': 23.3,
#   'Smoking History': 'Yes',
#   'Diabetes Status': 'No'},
#  {'Patient ID': '221',
#   'Age': '65',
#   'Gender': 'Male',
#   'Vaccination Date': '2022-02-10',
#   'Vaccine Dose': 'Booster',
#   'Pre-existing Conditions': 'Hypertension',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Fort Worth',
#   'Blood Pressure': 'Normal',
#   'Cholesterol Level': '180',
#   'BMI': 33.8,
#   'Smoking History': 'Yes',
#   'Diabetes Status': 'No'},
#  {'Patient ID': '982',
#   'Age': '74',
#   'Gender': 'Female',
#   'Vaccination Date': '2023-11-11',
#   'Vaccine Dose': '2nd Dose',
#   'Pre-existing Conditions': 'Diabetes',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'San Jose',
#   'Blood Pressure': 'Normal',
#   'Cholesterol Level': '210',
#   'BMI': 34.3,
#   'Smoking History': 'Yes',
#   'Diabetes Status': 'No'},
#  {'Patient ID': '443',
#   'Age': '25',
#   'Gender': 'Male',
#   'Vaccination Date': '2020-12-02',
#   'Vaccine Dose': '2nd Dose',
#   'Pre-existing Conditions': 'Asthma',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Columbus',
#   'Blood Pressure': 'Normal',
#   'Cholesterol Level': '350',
#   'BMI': 31.1,
#   'Smoking History': 'Yes',
#   'Diabetes Status': 'Yes'},
#  {'Patient ID': '320',
#   'Age': '82',
#   'Gender': 'Male',
#   'Vaccination Date': '2023-09-23',
#   'Vaccine Dose': 'Booster',
#   'Pre-existing Conditions': 'Heart Disease',
#   'Heart Attack Date': '2023-10-07',
#   'Heart Attack Related to Vaccine': True,
#   'Location': 'San Jose',
#   'Blood Pressure': 'Low',
#   'Cholesterol Level': '275',
#   'BMI': 28.7,
#   'Smoking History': 'Yes',
#   'Diabetes Status': 'Yes'},
#  {'Patient ID': '693',
#   'Age': '70',
#   'Gender': 'Male',
#   'Vaccination Date': '2022-04-07',
#   'Vaccine Dose': '2nd Dose',
#   'Pre-existing Conditions': 'Diabetes',
#   'Heart Attack Date': '2022-05-05',
#   'Heart Attack Related to Vaccine': True,
#   'Location': 'Columbus',
#   'Blood Pressure': 'Very Low',
#   'Cholesterol Level': '220',
#   'BMI': 20.6,
#   'Smoking History': 'Yes',
#   'Diabetes Status': 'Yes'},
#  {'Patient ID': '506',
#   'Age': '25',
#   'Gender': 'Male',
#   'Vaccination Date': '2021-04-05',
#   'Vaccine Dose': '1st Dose',
#   'Pre-existing Conditions': 'Heart Disease',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Columbus',
#   'Blood Pressure': 'High',
#   'Cholesterol Level': '350',
#   'BMI': 34.8,
#   'Smoking History': 'No',
#   'Diabetes Status': 'Yes'},
#  {'Patient ID': '848',
#   'Age': '41',
#   'Gender': 'Male',
#   'Vaccination Date': '2023-04-08',
#   'Vaccine Dose': '1st Dose',
#   'Pre-existing Conditions': 'None',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Washington',
#   'Blood Pressure': 'Low',
#   'Cholesterol Level': '220',
#   'BMI': 20.6,
#   'Smoking History': 'No',
#   'Diabetes Status': 'Yes'},
#  {'Patient ID': '979',
#   'Age': '74',
#   'Gender': 'Male',
#   'Vaccination Date': '2023-07-14',
#   'Vaccine Dose': 'Booster',
#   'Pre-existing Conditions': 'Hypertension',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Phoenix',
#   'Blood Pressure': 'Very Low',
#   'Cholesterol Level': '220',
#   'BMI': 25.7,
#   'Smoking History': 'No',
#   'Diabetes Status': 'Yes'},
#  {'Patient ID': '415',
#   'Age': '66',
#   'Gender': 'Male',
#   'Vaccination Date': '2020-03-05',
#   'Vaccine Dose': '2nd Dose',
#   'Pre-existing Conditions': 'Asthma',
#   'Heart Attack Date': '2002-08-06',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'San Diego',
#   'Blood Pressure': 'Low',
#   'Cholesterol Level': '300',
#   'BMI': 19.9,
#   'Smoking History': 'Yes',
#   'Diabetes Status': 'No'},
#  {'Patient ID': '742',
#   'Age': '23',
#   'Gender': 'Female',
#   'Vaccination Date': '2020-10-01',
#   'Vaccine Dose': 'Booster',
#   'Pre-existing Conditions': 'Heart Disease',
#   'Heart Attack Date': '2020-03-10',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Chicago',
#   'Blood Pressure': 'Very High',
#   'Cholesterol Level': '190',
#   'BMI': 39.4,
#   'Smoking History': 'Yes',
#   'Diabetes Status': 'Yes'},
#  {'Patient ID': '501',
#   'Age': '63',
#   'Gender': 'Male',
#   'Vaccination Date': '2021-07-16',
#   'Vaccine Dose': 'Booster',
#   'Pre-existing Conditions': 'None',
#   'Heart Attack Date': '2021-07-22',
#   'Heart Attack Related to Vaccine': True,
#   'Location': 'Denver',
#   'Blood Pressure': 'Low',
#   'Cholesterol Level': '350',
#   'BMI': 36.0,
#   'Smoking History': 'No',
#   'Diabetes Status': 'No'},
#  {'Patient ID': '135',
#   'Age': '50',
#   'Gender': 'Male',
#   'Vaccination Date': '2020-02-12',
#   'Vaccine Dose': 'Booster',
#   'Pre-existing Conditions': 'Asthma',
#   'Heart Attack Date': '2020-02-15',
#   'Heart Attack Related to Vaccine': True,
#   'Location': 'Seattle',
#   'Blood Pressure': 'High',
#   'Cholesterol Level': '220',
#   'BMI': 23.4,
#   'Smoking History': 'No',
#   'Diabetes Status': 'Yes'},
#  {'Patient ID': '989',
#   'Age': '30',
#   'Gender': 'Male',
#   'Vaccination Date': '2023-01-15',
#   'Vaccine Dose': '2nd Dose',
# ...
#   'Diabetes Status': 'Yes'},
#  {'Patient ID': '422',
#   'Age': '41',
#   'Gender': 'Female',
#   'Vaccination Date': '2022-05-29',
#   'Vaccine Dose': '1st Dose',
#   'Pre-existing Conditions': 'None',
#   'Heart Attack Date': '2022-06-04',
#   'Heart Attack Related to Vaccine': True,
#   'Location': 'Washington',
#   'Blood Pressure': 'Low',
#   'Cholesterol Level': '190',
#   'BMI': 30.0,
#   'Smoking History': 'Yes',
#   'Diabetes Status': 'Yes'},
#  {'Patient ID': '848',
#   'Age': '87',
#   'Gender': 'Female',
#   'Vaccination Date': '2020-01-16',
#   'Vaccine Dose': 'Booster',
#   'Pre-existing Conditions': 'Heart Disease',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Denver',
#   'Blood Pressure': 'Low',
#   'Cholesterol Level': '275',
#   'BMI': 22.1,
#   'Smoking History': 'No',
#   'Diabetes Status': 'Yes'},
#  {'Patient ID': '192',
#   'Age': '50',
#   'Gender': 'Female',
#   'Vaccination Date': '2023-08-17',
#   'Vaccine Dose': 'Booster',
#   'Pre-existing Conditions': 'Heart Disease',
#   'Heart Attack Date': '2023-08-21',
#   'Heart Attack Related to Vaccine': True,
#   'Location': 'Columbus',
#   'Blood Pressure': 'Low',
#   'Cholesterol Level': '250',
#   'BMI': 34.9,
#   'Smoking History': 'Yes',
#   'Diabetes Status': 'Yes'},
#  {'Patient ID': '671',
#   'Age': '48',
#   'Gender': 'Female',
#   'Vaccination Date': '2022-04-05',
#   'Vaccine Dose': '2nd Dose',
#   'Pre-existing Conditions': 'Hypertension',
#   'Heart Attack Date': '2020-01-22',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Philadelphia',
#   'Blood Pressure': 'Low',
#   'Cholesterol Level': '200',
#   'BMI': 23.1,
#   'Smoking History': 'No',
#   'Diabetes Status': 'No'},
#  {'Patient ID': '374',
#   'Age': '36',
#   'Gender': 'Male',
#   'Vaccination Date': '2022-03-13',
#   'Vaccine Dose': '1st Dose',
#   'Pre-existing Conditions': 'Heart Disease',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Charlotte',
#   'Blood Pressure': 'Normal',
#   'Cholesterol Level': '200',
#   'BMI': 24.0,
#   'Smoking History': 'Yes',
#   'Diabetes Status': 'Yes'},
#  {'Patient ID': '343',
#   'Age': '36',
#   'Gender': 'Female',
#   'Vaccination Date': '2022-03-19',
#   'Vaccine Dose': '1st Dose',
#   'Pre-existing Conditions': 'None',
#   'Heart Attack Date': '2022-04-18',
#   'Heart Attack Related to Vaccine': True,
#   'Location': 'Fort Worth',
#   'Blood Pressure': 'Very Low',
#   'Cholesterol Level': '210',
#   'BMI': 36.1,
#   'Smoking History': 'No',
#   'Diabetes Status': 'Yes'},
#  {'Patient ID': '978',
#   'Age': '36',
#   'Gender': 'Male',
#   'Vaccination Date': '2022-05-05',
#   'Vaccine Dose': '2nd Dose',
#   'Pre-existing Conditions': 'Heart Disease',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Phoenix',
#   'Blood Pressure': 'Normal',
#   'Cholesterol Level': '350',
#   'BMI': 27.1,
#   'Smoking History': 'No',
#   'Diabetes Status': 'No'},
#  {'Patient ID': '799',
#   'Age': '84',
#   'Gender': 'Male',
#   'Vaccination Date': '2023-02-08',
#   'Vaccine Dose': '2nd Dose',
#   'Pre-existing Conditions': 'Diabetes',
#   'Heart Attack Date': '2014-03-05',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Jacksonville',
#   'Blood Pressure': 'High',
#   'Cholesterol Level': '220',
#   'BMI': 23.1,
#   'Smoking History': 'No',
#   'Diabetes Status': 'No'},
#  {'Patient ID': '659',
#   'Age': '69',
#   'Gender': 'Female',
#   'Vaccination Date': '2021-02-28',
#   'Vaccine Dose': '1st Dose',
#   'Pre-existing Conditions': 'Heart Disease',
#   'Heart Attack Date': '2013-09-04',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Jacksonville',
#   'Blood Pressure': 'High',
#   'Cholesterol Level': '350',
#   'BMI': 24.3,
#   'Smoking History': 'Yes',
#   'Diabetes Status': 'Yes'},
#  {'Patient ID': '334',
#   'Age': '82',
#   'Gender': 'Male',
#   'Vaccination Date': '2023-01-30',
#   'Vaccine Dose': 'Booster',
#   'Pre-existing Conditions': 'Hypertension',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'New York',
#   'Blood Pressure': 'Very High',
#   'Cholesterol Level': '200',
#   'BMI': 39.8,
#   'Smoking History': 'No',
#   'Diabetes Status': 'Yes'},
#  {'Patient ID': '451',
#   'Age': '90',
#   'Gender': 'Male',
#   'Vaccination Date': '2023-10-23',
#   'Vaccine Dose': 'Booster',
#   'Pre-existing Conditions': 'Heart Disease',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Los Angeles',
#   'Blood Pressure': 'Low',
#   'Cholesterol Level': '350',
#   'BMI': 32.0,
#   'Smoking History': 'No',
#   'Diabetes Status': 'No'},
#  {'Patient ID': '578',
#   'Age': '48',
#   'Gender': 'Female',
#   'Vaccination Date': '2023-02-17',
#   'Vaccine Dose': '2nd Dose',
#   'Pre-existing Conditions': 'Hypertension',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'New York',
#   'Blood Pressure': 'Very High',
#   'Cholesterol Level': '250',
#   'BMI': 28.2,
#   'Smoking History': 'Yes',
#   'Diabetes Status': 'No'},
#  {'Patient ID': '249',
#   'Age': '50',
#   'Gender': 'Male',
#   'Vaccination Date': '2021-01-02',
#   'Vaccine Dose': '2nd Dose',
#   'Pre-existing Conditions': 'Diabetes',
#   'Heart Attack Date': '2004-02-02',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'San Jose',
#   'Blood Pressure': 'Very High',
#   'Cholesterol Level': '210',
#   'BMI': 18.8,
#   'Smoking History': 'Yes',
#   'Diabetes Status': 'Yes'},
#  {'Patient ID': '241',
#   'Age': '87',
#   'Gender': 'Male',
#   'Vaccination Date': '2022-10-31',
#   'Vaccine Dose': 'Booster',
#   'Pre-existing Conditions': 'Hypertension',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Seattle',
#   'Blood Pressure': 'Very Low',
#   'Cholesterol Level': '250',
#   'BMI': 23.4,
#   'Smoking History': 'Yes',
#   'Diabetes Status': 'No'},
#  {'Patient ID': '482',
#   'Age': '27',
#   'Gender': 'Female',
#   'Vaccination Date': '2021-12-15',
#   'Vaccine Dose': 'Booster',
#   'Pre-existing Conditions': 'Heart Disease',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Charlotte',
#   'Blood Pressure': 'Very Low',
#   'Cholesterol Level': '275',
#   'BMI': 19.9,
#   'Smoking History': 'Yes',
#   'Diabetes Status': 'Yes'},
#  {'Patient ID': '465',
#   'Age': '70',
#   'Gender': 'Male',
#   'Vaccination Date': '2020-10-27',
#   'Vaccine Dose': '1st Dose',
#   'Pre-existing Conditions': 'Heart Disease',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Columbus',
#   'Blood Pressure': 'Very Low',
#   'Cholesterol Level': '275',
#   'BMI': 34.9,
#   'Smoking History': 'Yes',
#   'Diabetes Status': 'Yes'},
#  {'Patient ID': '311',
#   'Age': '19',
#   'Gender': 'Female',
#   'Vaccination Date': '2022-02-20',
#   'Vaccine Dose': '1st Dose',
#   'Pre-existing Conditions': 'Diabetes',
#   'Heart Attack Date': '2012-08-19',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Boston',
#   'Blood Pressure': 'Normal',
#   'Cholesterol Level': '350',
#   'BMI': 23.3,
#   'Smoking History': 'No',
#   'Diabetes Status': 'Yes'},
#  {'Patient ID': '798',
#   'Age': '31',
#   'Gender': 'Male',
#   'Vaccination Date': '2020-02-21',
#   'Vaccine Dose': '2nd Dose',
#   'Pre-existing Conditions': 'Diabetes',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Jacksonville',
#   'Blood Pressure': 'Low',
#   'Cholesterol Level': '210',
#   'BMI': 37.6,
#   'Smoking History': 'No',
#   'Diabetes Status': 'Yes'},
#  {'Patient ID': '649',
#   'Age': '39',
#   'Gender': 'Female',
#   'Vaccination Date': '2022-07-24',
#   'Vaccine Dose': '1st Dose',
#   'Pre-existing Conditions': 'None',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Charlotte',
#   'Blood Pressure': 'Normal',
#   'Cholesterol Level': '210',
#   'BMI': 37.1,
#   'Smoking History': 'No',
#   'Diabetes Status': 'No'},
#  {'Patient ID': '565',
#   'Age': '73',
#   'Gender': 'Male',
#   'Vaccination Date': '2022-07-27',
#   'Vaccine Dose': 'Booster',
#   'Pre-existing Conditions': 'Diabetes',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Fort Worth',
#   'Blood Pressure': 'Normal',
#   'Cholesterol Level': '220',
#   'BMI': 37.2,
#   'Smoking History': 'No',
#   'Diabetes Status': 'Yes'},
#  {'Patient ID': '980',
#   'Age': '66',
#   'Gender': 'Male',
#   'Vaccination Date': '2020-02-03',
#   'Vaccine Dose': '1st Dose',
#   'Pre-existing Conditions': 'Diabetes',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'San Diego',
#   'Blood Pressure': 'Very High',
#   'Cholesterol Level': '350',
#   'BMI': 31.2,
#   'Smoking History': 'No',
#   'Diabetes Status': 'No'},
#  {'Patient ID': '590',
#   'Age': '85',
#   'Gender': 'Female',
#   'Vaccination Date': '2020-06-14',
#   'Vaccine Dose': '1st Dose',
#   'Pre-existing Conditions': 'Asthma',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Houston',
#   'Blood Pressure': 'Very High',
#   'Cholesterol Level': '300',
#   'BMI': 21.6,
#   'Smoking History': 'No',
#   'Diabetes Status': 'No'},
#  {'Patient ID': '213',
#   'Age': '44',
#   'Gender': 'Female',
#   'Vaccination Date': '2023-02-08',
#   'Vaccine Dose': '2nd Dose',
#   'Pre-existing Conditions': 'Asthma',
#   'Heart Attack Date': '2017-08-16',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Austin',
#   'Blood Pressure': 'Very Low',
#   'Cholesterol Level': '300',
#   'BMI': 28.5,
#   'Smoking History': 'Yes',
#   'Diabetes Status': 'No'},
#  {'Patient ID': '582',
#   'Age': '28',
#   'Gender': 'Male',
#   'Vaccination Date': '2021-03-19',
#   'Vaccine Dose': '1st Dose',
#   'Pre-existing Conditions': 'Heart Disease',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Philadelphia',
#   'Blood Pressure': 'Very High',
#   'Cholesterol Level': '210',
#   'BMI': 35.0,
#   'Smoking History': 'Yes',
#   'Diabetes Status': 'Yes'},
#  {'Patient ID': '458',
#   'Age': '82',
#   'Gender': 'Male',
#   'Vaccination Date': '2022-07-17',
#   'Vaccine Dose': 'Booster',
#   'Pre-existing Conditions': 'Heart Disease',
#   'Heart Attack Date': '2022-07-24',
#   'Heart Attack Related to Vaccine': True,
#   'Location': 'Seattle',
#   'Blood Pressure': 'High',
#   'Cholesterol Level': '250',
#   'BMI': 32.4,
#   'Smoking History': 'Yes',
#   'Diabetes Status': 'No'},
#  {'Patient ID': '741',
#   'Age': '23',
#   'Gender': 'Female',
#   'Vaccination Date': '2021-02-25',
#   'Vaccine Dose': 'Booster',
#   'Pre-existing Conditions': 'None',
#   'Heart Attack Date': '2007-03-06',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Boston',
#   'Blood Pressure': 'Very Low',
#   'Cholesterol Level': '300',
#   'BMI': 37.1,
#   'Smoking History': 'No',
#   'Diabetes Status': 'Yes'},
#  {'Patient ID': '775',
#   'Age': '47',
#   'Gender': 'Female',
#   'Vaccination Date': '2020-06-16',
#   'Vaccine Dose': 'Booster',
#   'Pre-existing Conditions': 'Asthma',
#   'Heart Attack Date': '2020-07-21',
#   'Heart Attack Related to Vaccine': True,
#   'Location': 'Chicago',
#   'Blood Pressure': 'Low',
#   'Cholesterol Level': '210',
#   'BMI': 20.6,
#   'Smoking History': 'Yes',
#   'Diabetes Status': 'No'},
#  {'Patient ID': '668',
#   'Age': '65',
#   'Gender': 'Male',
#   'Vaccination Date': '2020-06-05',
#   'Vaccine Dose': '1st Dose',
#   'Pre-existing Conditions': 'Heart Disease',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Columbus',
#   'Blood Pressure': 'Low',
#   'Cholesterol Level': '350',
#   'BMI': 27.9,
#   'Smoking History': 'Yes',
#   'Diabetes Status': 'No'},
#  {'Patient ID': '644',
#   'Age': '67',
#   'Gender': 'Female',
#   'Vaccination Date': '2021-01-10',
#   'Vaccine Dose': 'Booster',
#   'Pre-existing Conditions': 'Asthma',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Dallas',
#   'Blood Pressure': 'Very Low',
#   'Cholesterol Level': '250',
#   'BMI': 38.8,
#   'Smoking History': 'Yes',
#   'Diabetes Status': 'No'},
#  {'Patient ID': '422',
#   'Age': '38',
#   'Gender': 'Male',
#   'Vaccination Date': '2023-01-12',
#   'Vaccine Dose': '2nd Dose',
#   'Pre-existing Conditions': 'None',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'San Diego',
#   'Blood Pressure': 'High',
#   'Cholesterol Level': '250',
#   'BMI': 20.0,
#   'Smoking History': 'Yes',
#   'Diabetes Status': 'Yes'},
#  {'Patient ID': '201',
#   'Age': '27',
#   'Gender': 'Male',
#   'Vaccination Date': '2022-01-07',
#   'Vaccine Dose': '1st Dose',
#   'Pre-existing Conditions': 'Heart Disease',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Phoenix',
#   'Blood Pressure': 'Low',
#   'Cholesterol Level': '250',
#   'BMI': 23.8,
#   'Smoking History': 'No',
#   'Diabetes Status': 'Yes'},
#  {'Patient ID': '163',
#   'Age': '90',
#   'Gender': 'Male',
#   'Vaccination Date': '2021-01-28',
#   'Vaccine Dose': '1st Dose',
#   'Pre-existing Conditions': 'Heart Disease',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Seattle',
#   'Blood Pressure': 'Very High',
#   'Cholesterol Level': '220',
#   'BMI': 23.8,
#   'Smoking History': 'No',
#   'Diabetes Status': 'Yes'},
#  {'Patient ID': '705',
#   'Age': '74',
#   'Gender': 'Male',
#   'Vaccination Date': '2021-05-22',
#   'Vaccine Dose': '2nd Dose',
#   'Pre-existing Conditions': 'Heart Disease',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'San Diego',
#   'Blood Pressure': 'Very High',
#   'Cholesterol Level': '220',
#   'BMI': 36.2,
#   'Smoking History': 'No',
#   'Diabetes Status': 'No'},
#  {'Patient ID': '752',
#   'Age': '67',
#   'Gender': 'Male',
#   'Vaccination Date': '2021-11-11',
#   'Vaccine Dose': '2nd Dose',
#   'Pre-existing Conditions': 'Asthma',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Houston',
#   'Blood Pressure': 'Very Low',
#   'Cholesterol Level': '275',
#   'BMI': 28.1,
#   'Smoking History': 'No',
#   'Diabetes Status': 'No'},
#  {'Patient ID': '549',
#   'Age': '63',
#   'Gender': 'Female',
#   'Vaccination Date': '2023-05-23',
#   'Vaccine Dose': 'Booster',
#   'Pre-existing Conditions': 'Hypertension',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Columbus',
#   'Blood Pressure': 'Very Low',
#   'Cholesterol Level': '300',
#   'BMI': 32.4,
#   'Smoking History': 'Yes',
#   'Diabetes Status': 'No'},
#  {'Patient ID': '248',
#   'Age': '54',
#   'Gender': 'Female',
#   'Vaccination Date': '2022-12-22',
#   'Vaccine Dose': '1st Dose',
#   'Pre-existing Conditions': 'Asthma',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Denver',
#   'Blood Pressure': 'Very Low',
#   'Cholesterol Level': '300',
#   'BMI': 26.1,
#   'Smoking History': 'Yes',
#   'Diabetes Status': 'No'},
#  {'Patient ID': '252',
#   'Age': '62',
#   'Gender': 'Female',
#   'Vaccination Date': '2023-03-22',
#   'Vaccine Dose': '1st Dose',
#   'Pre-existing Conditions': 'None',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Charlotte',
#   'Blood Pressure': 'High',
#   'Cholesterol Level': '190',
#   'BMI': 28.7,
#   'Smoking History': 'Yes',
#   'Diabetes Status': 'Yes'},
#  {'Patient ID': '950',
#   'Age': '87',
#   'Gender': 'Female',
#   'Vaccination Date': '2020-08-20',
#   'Vaccine Dose': 'Booster',
#   'Pre-existing Conditions': 'Heart Disease',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Philadelphia',
#   'Blood Pressure': 'Very Low',
#   'Cholesterol Level': '275',
#   'BMI': 21.6,
#   'Smoking History': 'No',
#   'Diabetes Status': 'No'},
#  {'Patient ID': '592',
#   'Age': '67',
#   'Gender': 'Female',
#   'Vaccination Date': '2020-09-24',
#   'Vaccine Dose': '1st Dose',
#   'Pre-existing Conditions': 'Asthma',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Los Angeles',
#   'Blood Pressure': 'Normal',
#   'Cholesterol Level': '190',
#   'BMI': 31.9,
#   'Smoking History': 'Yes',
#   'Diabetes Status': 'No'},
#  {'Patient ID': '285',
#   'Age': '42',
#   'Gender': 'Female',
#   'Vaccination Date': '2020-02-16',
#   'Vaccine Dose': 'Booster',
#   'Pre-existing Conditions': 'None',
#   'Heart Attack Date': '',
#   'Heart Attack Related to Vaccine': False,
#   'Location': 'Chicago',
#   'Blood Pressure': 'Normal',
#   'Cholesterol Level': '275',
#   'BMI': 25.0,
#   'Smoking History': 'Yes',
#   'Diabetes Status': 'No'},
#  ...]
